# %% [markdown]
# ### Health Professional Shortage Areas (HPSA)

# %% [markdown]
# These data provide areas designated by HRSA as having shortages of primary care, dental care, or mental health providers. HRSA’s Bureau of Health Workforce (BHW) develops shortage designation criteria and uses them to decide whether or not a geographic area or population group is a Health Professional Shortage Area (HPSA), Medically Underserved Area (MUA), or Medically Underserved Population (MUP). More than 34 federal programs depend on HPSA/MUA/MUP designations to determine eligibility or as a funding preference. About 20 percent of the U.S. population resides in primary medical care HPSAs. HPSAs may have shortages of primary medical care, dental, or mental health providers; may be urban or rural areas; population groups; or medical or other public facilities.
#
# **HPSAs** are defined service areas that demonstrate a critical shortage of primary care physicians, dentists or mental health providers. A HPSA can be a distinct geographic area (such as a country, grouping, census tract, township or borough), a specific population group within a defined geographic area (such as the population under 200 percent of poverty) or a specific public or non-profit facility (such as a prison).

# %% [markdown]
# source: https://data.hrsa.gov/data/download
#
# I think the variable of interest here are the locations as county levels as
# fips or "State and County Federal Information Processing Standard Code" column
#
# * HPSA Score :
#     - This attribute represents the Health Professional Shortage Area (HPSA) Score developed by the National Health Service Corps (NHSC) in determining priorities for assignment of clinicians. The scores range from 0 to 26 where the higher the score, the greater the priority.
#
# others that we might find useful if we do timeseries
# *   HPSA Designation Date
# *   HPSA Designation Last Update Date
# *   HPSA Status : ['Withdrawn' 'Designated' 'Proposed For Withdrawal']
# *   'HPSA Withdrawn Date String', 'Withdrawn Date'
# *
#
#
#
# notes:
# - averaged the hpsa facility scores for all in the FIPS county area

# %%
import requests
import pandas as pd
data_path = 'data'
# Out:
# Mounted at /drive

# %%
shortage_df = pd.read_csv('https://data.hrsa.gov//DataDownload/DD_Files/BCD_HPSA_FCT_DET_PC.csv')

# %%
shortage_df  = shortage_df[(shortage_df['HPSA Status']=='Designated')|(shortage_df['HPSA Status']=='Proposed For Withdrawal')]
# shortage_df_remove_dups = shortage_df.drop(['HPSA Geography Identification Number', 'HPSA Component Name'], axis=1)
geo_shortage_designated_df = shortage_df[(shortage_df['Designation Type']=='Geographic HPSA')]
# hpsa component name varies 'census tract', but the other values are the same for that fips county
# so we need to drop duplicates 
geo_shortage_designated_df = geo_shortage_designated_df.drop_duplicates()

geo_shortage_designated_df.rename(columns={'State and County Federal Information Processing Standard Code': 'FIPS'}, inplace=True)

# %%
geo_shortage_designated_df[geo_shortage_designated_df['FIPS']=='04019'][['HPSA Component Name', 'FIPS', 'Designation Type', 'HPSA Name', 'HPSA Score']]
# Out:
#                             HPSA Component Name   FIPS Designation Type  \
# 15580                                     41.19  04019  Geographic HPSA
# 15581                                     43.29  04019  Geographic HPSA
# 15582                                     43.26  04019  Geographic HPSA
# 15583                                     43.27  04019  Geographic HPSA
# 15584                                     43.23  04019  Geographic HPSA
# 20082     Census Tract 53, Pima County, Arizona  04019  Geographic HPSA
# 20083  Census Tract 40.52, Pima County, Arizona  04019  Geographic HPSA
# 20084  Census Tract 40.51, Pima County, Arizona  04019  Geographic HPSA
# 20085  Census Tract 40.50, Pima County, Arizona  04019  Geographic HPSA
# 20086  Census Tract 40.54, Pima County, Arizona  04019  Geographic HPSA
# 20087  Census Tract 40.53, Pima County, Arizona  04019  Geographic HPSA
# 20095                                      9410  04019  Geographic HPSA
# 41143  Census Tract 44.23, Pima County, Arizona  04019  Geographic HPSA
# 41144  Census Tract 44.25, Pima County, Arizona  04019  Geographic HPSA
# 60721     Census Tract 52, Pima County, Arizona  04019  Geographic HPSA
# 60749  Census Tract 40.43, Pima County, Arizona  04019  Geographic HPSA
# 60750  Census Tract 40.42, Pima County, Arizona  04019  Geographic HPSA
# 60751  Census Tract 40.44, Pima County, Arizona  04019  Geographic HPSA
# 60752  Census Tract 40.26, Pima County, Arizona  04019  Geographic HPSA
# 60753  Census Tract 40.64, Pima County, Arizona  04019  Geographic HPSA
# 60754  Census Tract 40.65, Pima County, Arizona  04019  Geographic HPSA
# 60755  Census Tract 40.73, Pima County, Arizona  04019  Geographic HPSA
# 60756  Census Tract 40.74, Pima County, Arizona  04019  Geographic HPSA
# 60757  Census Tract 40.66, Pima County, Arizona  04019  Geographic HPSA
# 60758  Census Tract 40.62, Pima County, Arizona  04019  Geographic HPSA
# 60759  Census Tract 40.63, Pima County, Arizona  04019  Geographic HPSA
# 62720  Census Tract 41.07, Pima County, Arizona  04019  Geographic HPSA
# 62721  Census Tract 40.61, Pima County, Arizona  04019  Geographic HPSA
# 62722  Census Tract 41.09, Pima County, Arizona  04019  Geographic HPSA
#
#                 HPSA Name  HPSA Score
# 15580           Sahuarita          10
# 15581           Sahuarita          10
# 15582           Sahuarita          10
# 15583           Sahuarita          10
# 15584           Sahuarita          10
# 20082        Tanque Verde          11
# 20083        Tanque Verde          11
# 20084        Tanque Verde          11
# 20085        Tanque Verde          11
# 20086        Tanque Verde          11
# 20087        Tanque Verde          11
# 20095  Pascua Yaqui Tribe          20
# 41143       Picture Rocks          12
# 41144       Picture Rocks          12
# 60721                 Ajo          17
# 60749   Tucson South East           9
# 60750   Tucson South East           9
# 60751   Tucson South East           9
# 60752   Tucson South East           9
# 60753   Tucson South East           9
# 60754   Tucson South East           9
# 60755   Tucson South East           9
# 60756   Tucson South East           9
# 60757   Tucson South East           9
# 60758   Tucson South East           9
# 60759   Tucson South East           9
# 62720                Vail          13
# 62721                Vail          13
# 62722                Vail          13

# %%
# geo_shortage_designated_df[['FIPS', 'HPSA Score']].groupby('FIPS').count().sort_values(by='HPSA Score', ascending=False)

geo_shortage_designated_df
# Out:
#                                           HPSA Name     HPSA ID  \
# 207                 Rock Lake/LA Cross Service Area  1538714311
# 209                                        Enumclaw  1538700586
# 222                                   Island County  1538396778
# 228                            North Spokane County  1538067837
# 634                                   Morrow County  1413297457
# ...                                             ...         ...
# 63620                                Conejos County  1086689702
# 63624                                 Moffat County  1086098043
# 63824  MSSA 188.1-Big Bend/Montgomery Creek/Oak Run  1066701732
# 63825                                MSSA 73/Bieber  1066701137
# 63968                          Skagway Municipality  1021026875
#
#       Designation Type HPSA Discipline Class  HPSA Score  \
# 207    Geographic HPSA          Primary Care          15
# 209    Geographic HPSA          Primary Care          12
# 222    Geographic HPSA          Primary Care          13
# 228    Geographic HPSA          Primary Care          16
# 634    Geographic HPSA          Primary Care          11
# ...                ...                   ...         ...
# 63620  Geographic HPSA          Primary Care          21
# 63624  Geographic HPSA          Primary Care          12
# 63824  Geographic HPSA          Primary Care          14
# 63825  Geographic HPSA          Primary Care          10
# 63968  Geographic HPSA          Primary Care           9
#
#       Primary State Abbreviation              HPSA Status  \
# 207                           WA  Proposed For Withdrawal
# 209                           WA               Designated
# 222                           WA               Designated
# 228                           WA               Designated
# 634                           OR               Designated
# ...                          ...                      ...
# 63620                         CO               Designated
# 63624                         CO  Proposed For Withdrawal
# 63824                         CA               Designated
# 63825                         CA  Proposed For Withdrawal
# 63968                         AK               Designated
#
#       HPSA Designation Date HPSA Designation Last Update Date  \
# 207              03/24/1987                        09/09/2021
# 209              09/18/2017                        09/10/2021
# 222              07/21/2017                        09/10/2021
# 228              09/15/2017                        09/08/2021
# 634              09/21/2020                        09/10/2021
# ...                     ...                               ...
# 63620            04/05/2017                        09/10/2021
# 63624            04/04/2017                        09/09/2021
# 63824            06/22/2022                        06/22/2022
# 63825            04/24/2017                        09/10/2021
# 63968            05/10/2013                        09/10/2021
#
#       Metropolitan Indicator  ... Rural Status Code State Abbreviation   FIPS  \
# 207                  Unknown  ...                 R                 WA  53075
# 209                  Unknown  ...                 N                 WA  53033
# 222                  Unknown  ...                 R                 WA  53029
# 228                  Unknown  ...                 N                 WA  53063
# 634                  Unknown  ...                 R                 OR  41049
# ...                      ...  ...               ...                ...    ...
# 63620                Unknown  ...                 R                 CO  08021
# 63624                Unknown  ...                 R                 CO  08081
# 63824                Unknown  ...                 R                 CA  06089
# 63825                Unknown  ...                 R                 CA  06035
# 63968                Unknown  ...                 R                 AK  02230
#
#        State FIPS Code  State Name  \
# 207                 53  Washington
# 209                 53  Washington
# 222                 53  Washington
# 228                 53  Washington
# 634                 41      Oregon
# ...                ...         ...
# 63620                8    Colorado
# 63624                8    Colorado
# 63824                6  California
# 63825                6  California
# 63968                2      Alaska
#
#       U.S. - Mexico Border 100 Kilometer Indicator  \
# 207                                              N
# 209                                              N
# 222                                              N
# 228                                              N
# 634                                              N
# ...                                            ...
# 63620                                            N
# 63624                                            N
# 63824                                            N
# 63825                                            N
# 63968                                            N
#
#       U.S. - Mexico Border County Indicator Data Warehouse Record Create Date  \
# 207                                       N                        07/18/2022
# 209                                       N                        07/18/2022
# 222                                       N                        07/18/2022
# 228                                       N                        07/18/2022
# 634                                       N                        07/18/2022
# ...                                     ...                               ...
# 63620                                     N                        07/18/2022
# 63624                                     N                        07/18/2022
# 63824                                     N                        07/18/2022
# 63825                                     N                        07/18/2022
# 63968                                     N                        07/18/2022
#
#       Data Warehouse Record Create Date Text  Unnamed: 65
# 207                               2022/07/18          NaN
# 209                               2022/07/18          NaN
# 222                               2022/07/18          NaN
# 228                               2022/07/18          NaN
# 634                               2022/07/18          NaN
# ...                                      ...          ...
# 63620                             2022/07/18          NaN
# 63624                             2022/07/18          NaN
# 63824                             2022/07/18          NaN
# 63825                             2022/07/18          NaN
# 63968                             2022/07/18          NaN
#
# [1200 rows x 64 columns]

# %%
geo_shortage_designated_df_trunc = geo_shortage_designated_df[['FIPS', 'HPSA Score']]
# multiple fips codes 
grouped_shortages_fips_df = geo_shortage_designated_df.groupby('FIPS')['HPSA Score'].mean().reset_index()

# %%
len(grouped_shortages_fips_df['FIPS'].unique())
# Out:
# 965

# %%
grouped_shortages_fips_df
# Out:
#       FIPS  HPSA Score
# 0    01001        12.0
# 1    01007        10.0
# 2    01009         7.0
# 3    01017        14.0
# 4    01019        11.0
# ..     ...         ...
# 960  69085        16.0
# 961  69100        16.0
# 962  69110        16.0
# 963  69120        16.0
# 964  78020        18.0
#
# [965 rows x 2 columns]

# %%
grouped_shortages_fips_df.to_csv(f'{data_path}/processed/FIPS_HPSA_PC.csv', index=False)
grouped_shortages_fips_df
# Out:
#       FIPS  HPSA Score
# 0    01001        12.0
# 1    01007        10.0
# 2    01009         7.0
# 3    01017        14.0
# 4    01019        11.0
# ..     ...         ...
# 960  69085        16.0
# 961  69100        16.0
# 962  69110        16.0
# 963  69120        16.0
# 964  78020        18.0
#
# [965 rows x 2 columns]

# %% [markdown]
# #### If we want to do subopulations:

# %%
# If we wanted to do subpopulations: 
shortage_df['HPSA Population Type'].unique()
# Out:
# array(['Native American Population HPSA', 'Geographic Population',
#        'Low Income Population HPSA', nan,
#        'Low Income Homeless Population HPSA',
#        'Low Income Homeless Migrant Seasonal Worker Population HPSA',
#        'Low Income Migrant Seasonal Worker Population HPSA',
#        'Medicaid Eligible Population HPSA',
#        'Low Income Migrant Farmworker Population HPSA',
#        'Migrant Farmworker Population HPSA',
#        'Low Income Homeless Migrant Farmworker Population HPSA',
#        'Other Population HPSA', 'Homeless Population HPSA',
#        'Migrant Seasonal Worker Population HPSA'], dtype=object)

# %%
# IF we want to do subcategories 
import numpy as np
shortage_df = geo_shortage_designated_df

# core_cities_df['HPSA Low Income Pop. Score'] = core_cities_df.apply(lambda x: x['HPSA Score'] if x['HPSA Population Type'] is 'Low Income Population HPSA' else np.nan)
shortage_df['HPSA Low Income Pop. Score'] = np.where((shortage_df['HPSA Population Type'] == 'Low Income Population HPSA'), shortage_df['HPSA Score'], np.nan)
shortage_df['HPSA Geo Score'] = np.where((shortage_df['HPSA Population Type'] == 'Geographic Population'), shortage_df['HPSA Score'], np.nan)
shortage_df[(np.isnan(shortage_df['HPSA Low Income Pop. Score']))&(np.isnan(shortage_df['HPSA Geo Score']))]
